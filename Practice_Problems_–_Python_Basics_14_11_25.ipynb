# %% [markdown]
# #Write a Python program that takes an integer as input and calculates the
# #sum of its digits

# %%
n = int(input("Enter a number: "))
print("Sum of digits:", sum(int(digit) for digit in str(abs(n))))
# Out:
# Enter a number: 1345
# Sum of digits: 13

# %% [markdown]
# #Create a Python program to calculate the factorial of a given number using a function.

# %%
def factorial(n):
    """Calculate the factorial of a non-negative integer n."""
    if n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0 or n == 1:
        return 1
    else:
        result = 1
        for i in range(2, n + 1):
            result *= i
        return result

# %%
number = int(input("Enter a non-negative integer: "))
print(f"The factorial of {number} is {factorial(number)}")
# Out:
# Enter a non-negative integer: 2
# The factorial of 2 is 2

# %% [markdown]
# #Develop a Python program that checks whether a given word or phrase is palindrome.

# %%
def is_palindrome(text):
    text = text.lower().replace(" ", "")
    print (text[::-1])
    return text == text[::-1]

# %%
word = input("Enter a word or phrase: ")
if is_palindrome(word):
    print("It's a palindrome!")
else:
    print("It's not a palindrome.")
# Out:
# Enter a word or phrase: Malayalam
# malayalam
# It's a palindrome!

# %% [markdown]
# #Create a Python program that takes a sentence as input and counts the number of vowels and consonants.

# %%
def count_vowels_consonants(sentence):
    vowels = "aeiouAEIOU"
    vowel_count = 0
    consonant_count = 0

    for char in sentence:
        if char.isalpha():
            if char in vowels:
                vowel_count += 1
            else:
                consonant_count += 1

    return vowel_count, consonant_count

# %%
text = input("Enter a sentence: ")
vowels, consonants = count_vowels_consonants(text)
print(f"Vowels: {vowels}")
print(f"Consonants: {consonants}")
# Out:
# Enter a sentence: i am Junaida. I like reading
# Vowels: 12
# Consonants: 10

# %% [markdown]
# #Develop a Python program that takes two lists as input and returns a new list containing the common elements between them.

# %%
def find_common_elements(list1, list2):
    return list(set(list1) & set(list2))

# %%
# Example usage
list1 = input("Enter the first list of elements: ").split(",")
list2 = input("Enter the second list of elements: ").split(",")
# Out:
# Enter the first list of elements: 1,2,3,4,5,6
# Enter the second list of elements: 1,6,4,7,8

# %%
common = find_common_elements(list1, list2)
print("Common elements:", common)
# Out:
# Common elements: ['6', '4', '1']

# %% [markdown]
# #Write a Python program that takes a string as input and counts the frequency of each character in the string.

# %%
def count_char_frequency(text):
    frequency = {}
    for char in text:
        if char in frequency:
            frequency[char] += 1
        else:
            frequency[char] = 1
    return frequency

# %%
input_string = input("Enter a string: ")
char_freq = count_char_frequency(input_string)

print("Character frequencies:")
for char, freq in char_freq.items():
    print(f"'{char}': {freq}")
# Out:
# Enter a string: junaida
# Character frequencies:
# 'j': 1
# 'u': 1
# 'n': 1
# 'a': 2
# 'i': 1
# 'd': 1

# %% [markdown]
# #Develop a Python program that checks if a given year is a leap year.

# %%
def is_leap_year(year):
    """
    Returns True if the given year is a leap year, False otherwise.
    """
    if (year % 4 == 0):
        if (year % 100 != 0) or (year % 400 == 0):
            return True
    return False

# %%
year = int(input("Enter a year: "))
if is_leap_year(year):
  print(f"{year} is a leap year.")
else:
  print(f"{year} is not a leap year.")
# Out:
# Enter a year: 2004
# 2004 is a leap year.

# %% [markdown]
# #Write a Python program that checks if a given number, is a prime number.

# %%
def is_prime(n):
    """
    Returns True if n is a prime number, False otherwise.
    """
    if n <= 1:
        return False
    if n == 2:
        return True
    if n % 2 == 0:
        return False
    for i in range(3, int(n**0.5) + 1, 2):
        if n % i == 0:
            return False
    return True

# %%
number = int(input("Enter a number: "))
if is_prime(number):
  print(f"{number} is a prime number.")
else:
  print(f"{number} is not a prime number.")
# Out:
# Enter a number: 3
# 3 is a prime number.

# %% [markdown]
# #Write a Python program to generate the Fibonacci sequence up to a specified number of terms.

# %%
def generate_fibonacci(n):
    """
    Generates the Fibonacci sequence up to n terms.
    """
    sequence = []
    a, b = 0, 1
    for i in range(n):
        sequence.append(a)
        a, b = b, a + b
    return sequence

# %%
terms = int(input("Enter the number of terms: "))
if terms <= 0:
  print("Please enter a positive integer.")
else:
  fib_sequence = generate_fibonacci(terms)
  print("Fibonacci sequence:")
  print(fib_sequence)
# Out:
# Enter the number of terms: 5
# Fibonacci sequence:
# [0, 1, 1, 2, 3]

# %% [markdown]
# #Write a python program to find the roots of a quadratic equation

# %%
import cmath  # for complex number support

# Input coefficients
a = float(input("Enter coefficient a: "))
b = float(input("Enter coefficient b: "))
c = float(input("Enter coefficient c: "))

# Calculate the discriminant
d = cmath.sqrt(b**2 - 4*a*c)

# Calculate the two roots
root1 = (-b + d) / (2*a)
root2 = (-b - d) / (2*a)

# Display the results
print(f"The roots of the equation are: {root1} and {root2}")
# Out:
# Enter coefficient a: 3
# Enter coefficient b: 2
# Enter coefficient c: 5
# The roots of the equation are: (-0.3333333333333333+1.247219128924647j) and (-0.3333333333333333-1.247219128924647j)
